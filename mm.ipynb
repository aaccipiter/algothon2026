# %%
ETF bid - 7k > FLY / 2
Long fly short etf

# %%
Fly bid / 2 + 50 > ETF ask - 7000

Long etf short fly

# %% [markdown]
# Depending on absolute net exposure then move quoting up or down by fixed amount
